# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\raula\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\raula\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('HRDataset_v14.csv')
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# F     176
# M     135
# Name: count, dtype: int64

# %%
mpl.style.use("ggplot")

# %%
sns.kdeplot(data = df, x = "Salary", hue = "Sex")
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(12,10))
ax.hist(df["Salary"])
# Out:
# (array([197.,  65.,  32.,   7.,   2.,   3.,   3.,   0.,   1.,   1.]),
#  array([ 45046. ,  65541.4,  86036.8, 106532.2, 127027.6, 147523. ,
#         168018.4, 188513.8, 209009.2, 229504.6, 250000. ]),
#  <BarContainer object of 10 artists>)

# %%
fig
ax.set_title("Sálarios mais populares")
ax.set_xlabel("Valor do Sálario em R$")
ax.set_ylabel("nº de funcionários")
fig

# %%
print("A faixa salarial mais popular dentro da empresa é até R$ 50.000,00")
# Out:
# A faixa salarial mais popular dentro da empresa é até R$ 50.000,00

# %%
ax1 = sns.catplot(data = df, kind='violin', y = df["Salary"], x = df["Sex"], split = True)
ax1.set(ylabel = 'Valor do Salário em R$', xlabel = "Gênero do funcionário", title = 'Faixa salarial por gênero')
ax1

# %%
df_data = pd.DatetimeIndex(df['DateofHire']) #transformando a coluna DateofHire em data

# %%
df['Ano Contratação'] = df_data.year #pegando somente o ano da data
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    ManagerID  RecruitmentSource PerformanceScore EngagementSurvey  \
# ...

# %%
df.index = df['Ano Contratação'].sort_values() #definindo o index em ordem crescente
df
# Out:
#                             Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# Ano Contratação
# 2006                  Adinolfi, Wilson  K  10026          0                0
# 2007             Ait Sidi, Karthikeyan     10084          1                1
# 2007                    Akinkuolie, Sarah  10196          1                1
# 2008                         Alagbe,Trina  10088          1                1
# 2008                     Anderson, Carol   10069          0                2
# ...                                   ...    ...        ...              ...
# 2017                       Woodson, Jason  10135          0                0
# 2017                   Ybarra, Catherine   10301          0                0
# 2017                     Zamora, Jennifer  10010          0                0
# 2017                          Zhou, Julia  10043          0                0
# 2018                        Zima, Colleen  10271          0                4
#
# ...

# %%
y = df.index.value_counts().sort_index() #visualizando valores para gerar gráfico
y
# Out:
# Ano Contratação
# 2006     1
# 2007     2
# 2008     3
# 2009     7
# 2010     9
# 2011    83
# 2012    45
# 2013    44
# 2014    60
# 2015    36
# 2016    14
# 2017     6
# 2018     1
# Name: count, dtype: int64

# %%
fig1, ax1 = plt.subplots(figsize = (12,10)) #definindo tamanho da imagem

# %%
ax1.plot(y) #plotando variável y
fig1 #exibindo série temporal baseado em quantidade de contratações por ano

# %%
ax1.set_title('Nº Contratações x Ano') #definindo título do gráfico
ax1.set_xlabel('Ano') # definindo rótulo eixo X
ax1.set_ylabel('Nº Contratações') #definindo rótulo eixo Y
fig1

# %%
df_st = pd.DataFrame(data= y, index= df.index.unique())
df_st
# Out:
#                  count
# Ano Contratação
# 2006                 1
# 2007                 2
# 2008                 3
# 2009                 7
# 2010                 9
# 2011                83
# 2012                45
# 2013                44
# 2014                60
# 2015                36
# 2016                14
# 2017                 6
# 2018                 1

# %%
fig3, ax3 = plt.subplots()
ax3.plot(df.index.unique(),y)
